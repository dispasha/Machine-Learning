# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import precision_recall_curve, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

# %%
cl = pd.read_csv('classification.csv')
cl = cl.replace({0:False, 1:True})

# %%
y_t = cl['true']
y_p = cl['pred']

# %%
TP = (y_t & y_p).value_counts()[True]
TN = (np.invert(y_t) & np.invert(y_p)).value_counts()[True]
FN = (y_t & np.invert(y_p)).value_counts()[True]
FP = (np.invert(y_t) & y_p).value_counts()[True]

# %%
print(TP, FP, FN, TN)
# Out:
# 43 34 59 64

# %%
43+59+34+64
# Out:
# 200

# %%
print(accuracy_score(y_t, y_p), precision_score(y_t, y_p), recall_score(y_t, y_p), f1_score(y_t, y_p))
# Out:
# 0.535 0.5584415584415584 0.4215686274509804 0.48044692737430167

# %%
43/(43+59)
# Out:
# 0.4215686274509804

# %%
clfs = pd.read_csv('scores.csv')

# %%
clfs
# Out:
#      true  score_logreg  score_svm  score_knn  score_tree
# 0       0      0.683832   0.145976   0.787063    0.500000
# 1       1      0.801966   0.239511   1.000000    0.833333
# 2       0      0.382315  -0.245701   0.000000    0.000000
# 3       1      0.506797  -0.137058   0.000000    0.105263
# 4       1      0.488781  -0.154148   0.000000    0.105263
# ..    ...           ...        ...        ...         ...
# 195     0      0.573801  -0.088203   0.284192    0.400000
# 196     0      0.624422  -0.012315   0.205437    0.400000
# 197     1      0.425538  -0.135673   0.382351    0.700000
# 198     0      0.905270   0.583806   1.000000    1.000000
# 199     0      0.275594  -0.422160   0.743567    0.642857
#
# [200 rows x 5 columns]

# %%
for i in clfs.drop('true', axis=1).columns:
    print(i, roc_auc_score(clfs['true'], clfs[i]))
# Out:
# score_logreg 0.719187675070028
# score_svm 0.7086834733893557
# score_knn 0.6351540616246498
# score_tree 0.6919267707082833

# %%
for i in clfs.drop('true', axis=1).columns:
    pr_rec = precision_recall_curve(clfs['true'], clfs[i])[0:2]
    pr_rec = pd.DataFrame(np.transpose(np.array([pr_rec[0], pr_rec[1]])))
    print(i, np.max(pr_rec[pr_rec[1]>0.7][0]))
# Out:
# score_logreg 0.6302521008403361
# score_svm 0.6228070175438597
# score_knn 0.6065573770491803
# score_tree 0.6517857142857143

# %%
# Out:
# (array([0.49246231, 0.48989899, 0.49238579, 0.48979592, 0.49230769,
#         0.49484536, 0.49740933, 0.5       , 0.4973822 , 0.49473684,
#         0.49206349, 0.49468085, 0.4973262 , 0.5       , 0.4972973 ,
#         0.5       , 0.50273224, 0.50549451, 0.50828729, 0.51111111,
#         0.51396648, 0.51685393, 0.51977401, 0.52272727, 0.52571429,
#         0.52298851, 0.52601156, 0.52906977, 0.53216374, 0.53529412,
#         0.53846154, 0.54166667, 0.54491018, 0.54819277, 0.54545455,
#         0.54878049, 0.55214724, 0.55555556, 0.55279503, 0.55      ,
#         0.54716981, 0.55063291, 0.5477707 , 0.54487179, 0.5483871 ,
#         0.55194805, 0.55555556, 0.55921053, 0.56291391, 0.56666667,
#         0.5704698 , 0.57432432, 0.57142857, 0.57534247, 0.57931034,
#         0.58333333, 0.58741259, 0.5915493 , 0.58865248, 0.59285714,
#         0.58992806, 0.5942029 , 0.59124088, 0.58823529, 0.59259259,
#         0.59701493, 0.59398496, 0.59090909, 0.59541985, 0.6       ,
# ...
